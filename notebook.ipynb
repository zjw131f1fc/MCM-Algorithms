# %% [markdown]
# # MCM Algorithms Demo
#
# This notebook demonstrates the usage of algorithms in the MCM-Algorithms repository.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Example Usage
#
# Add your code here...

# %%
# 新添加的代码块
data = np.random.randn(100)
print(f"数据均值: {data.mean():.4f}")
